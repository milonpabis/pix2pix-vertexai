# %%
from google.colab import userdata
import os

github_token = userdata.get('GITHUB_PAT') # Use the name you gave your secret

github_username = "milonpabis" # Replace with your actual GitHub username

# 4. Clone the repository using the PAT
# The PAT is embedded in the URL as a "password"
# We're using f-strings for clarity here
# !git clone https://oauth2:{github_token}@github.com/{github_username}/pix2pix.git # <-- UNCOMMENT IF WANT TO CLONE

# Alternative for older git versions or if the above doesn't work:
# !git clone https://{github_username}:{github_token}@github.com/{github_username}/your_private_repo_name.git

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("balraj98/facades-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/balraj98/facades-dataset?dataset_version_number=1...
# 100%|██████████| 33.5M/33.5M [00:02<00:00, 13.2MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/balraj98/facades-dataset/versions/1

# %%
# !mkdir data

# %%
# !cp -r /root/.cache/kagglehub/datasets/balraj98/facades-dataset/versions/1/* data/

# %%
import os
import argparse
from tqdm import tqdm
import random as rd
import datetime as dt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from torch.utils.tensorboard import SummaryWriter
from torch.nn.init import normal_, constant_
from torchvision.utils import save_image

import PIL
from PIL import Image
import numpy as np

# %%
LEAKY_RELU_SLOPE = 0.2
KERNEL_SIZE = 4
STRIDE = 2
PADDING = 1
DROPOUT_RATE = 0.5
EPOCHS = 200
BATCH_SIZE = 1
LEARNING_RATE = 0.0002
BETA1 = 0.5
BETA2 = 0.999

WEIGHTS_MEAN = 0.0
WEIGHTS_STD = 0.02

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        m.weight.data.normal_(0.0, 0.02)
    elif classname.find('BatchNorm2d') != -1:
        m.weight.data.normal_(1.0, 0.02)
        m.bias.data.fill_(0)

# %%
import albumentations as A
from albumentations.pytorch import ToTensorV2

both_transform = A.Compose(
    [
        A.Resize(width=256, height=256),
        A.HorizontalFlip(p=0.5)
    ],
    additional_targets={"image0": "image"},
)

transform_only_input = A.Compose(
    [
        A.ColorJitter(p=0.2),
        A.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5], max_pixel_value=255.0,),
        ToTensorV2(),
    ]
)

transform_only_mask = A.Compose(
    [
        A.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5], max_pixel_value=255.0,),
        ToTensorV2(),
    ]
)

class MapDataset(Dataset):
    def __init__(self, root_dir: str, target_side: str = "right"):
        self.root_dir = root_dir
        self.list_files = os.listdir(self.root_dir)
        self.size = self._infer_shape()
        self.target_side = target_side

    def _infer_shape(self) -> int:
        image_path = os.path.join(self.root_dir, self.list_files[0])
        image = Image.open(image_path)
        return int(image.size[0] / 2)

    def __len__(self):
        return len(self.list_files)

    def __getitem__(self, index):
        img_file = self.list_files[index]
        img_path = os.path.join(self.root_dir, img_file)
        image = np.array(Image.open(img_path))
        input_image = image[:, :self.size, :]
        target_image = image[:, self.size:, :]

        augmentations = both_transform(image=input_image, image0=target_image)
        input_image = augmentations["image"]
        target_image = augmentations["image0"]

        input_image = transform_only_input(image=input_image)["image"]
        target_image = transform_only_mask(image=target_image)["image"]
        if self.target_side == "right":
            return input_image, target_image
        return target_image, input_image

# %%
class Block(nn.Module):

    def __init__(self, in_ch: int, out_ch: int, add_norm: bool, add_drop: bool, add_activation: bool, down: bool, activation_fun: str, stride: int = 2) -> None:
        """
        Universal block for generator and discriminator.

        Parameters
        ----------

        in_ch: (int) Number of input channels.
        out_ch: (int) Number of output channels.
        add_norm: (bool) Add normalization layer.
        add_drop: (bool) Add dropout layer.
        add_activation: (bool) Add activation layer.
        down: (bool) Downsample or upsample.
        activation_fun: (str) Activation function. ('leaky' -> LeakyReLU, '...' -> ReLU)
        """
        super(Block, self).__init__()
        try:
            down_sample = nn.Conv2d(in_ch, out_ch, kernel_size=KERNEL_SIZE, stride=stride, padding=PADDING, padding_mode="reflect")
            up_sample = nn.ConvTranspose2d(in_ch, out_ch, kernel_size=KERNEL_SIZE, stride=stride, padding=PADDING)

            self.conv = down_sample if down else up_sample
            # self.norm = nn.InstanceNorm2d(out_ch, affine=True)
            self.norm = nn.BatchNorm2d(out_ch, affine=True)
            self.activation = nn.LeakyReLU(LEAKY_RELU_SLOPE) if activation_fun == "leaky" else nn.ReLU()
            self.dropout = nn.Dropout(DROPOUT_RATE)

            self.add_drop = add_drop
            self.add_norm = add_norm
            self.add_activation = add_activation

        except Exception as e:
            print(f"Error: {e}")

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.conv(x)
        if self.add_norm:
            x = self.norm(x)
        if self.add_drop:
            x = self.dropout(x)
        if self.add_activation:
            x = self.activation(x)
        return x

# %%
class PatchGAN70x70(nn.Module):

    def __init__(self, in_ch: int) -> None:
        """
        PatchGAN discriminator
        """

        super(PatchGAN70x70, self).__init__()

        self.model = nn.Sequential(
            Block(in_ch*2, 64, add_norm=False, add_drop=False, add_activation=True, down=True, activation_fun="leaky"),
            Block(64, 128, add_norm=True, add_drop=False, add_activation=True, down=True, activation_fun="leaky"),
            Block(128, 256, add_norm=True, add_drop=False, add_activation=True, down=True, activation_fun="leaky"),
            Block(256, 512, add_norm=True, add_drop=False, add_activation=True, down=True, activation_fun="leaky", stride=1)
        )

        self.out = nn.Conv2d(512, 1, kernel_size=4, stride=1, padding=1, padding_mode="reflect")
        self.activation = nn.Sigmoid()

    def forward(self, source_x: torch.Tensor, target_x: torch.Tensor) -> torch.Tensor:
        x = self.model(torch.cat([source_x, target_x], dim=1))
        x = self.out(x)
        x = self.activation(x)
        return x

# %%
class UNETGenerator(nn.Module):

    def __init__(self, in_ch: int) -> None:
        """
        U-Net Generator with skip connections and Instance Normalization.
        """

        super(UNETGenerator, self).__init__()

        self.in1 = Block(in_ch, 64, add_norm=False, add_drop=False, add_activation=True, down=True, activation_fun="leaky")
        self.e1 = Block(64, 128, add_norm=True, add_drop=False, add_activation=True, down=True, activation_fun="leaky")
        self.e2 = Block(128, 256, add_norm=True, add_drop=False, add_activation=True, down=True, activation_fun="leaky")
        self.e3 = Block(256, 512, add_norm=True, add_drop=False, add_activation=True, down=True, activation_fun="leaky")
        self.e4 = Block(512, 512, add_norm=True, add_drop=False, add_activation=True, down=True, activation_fun="leaky")
        self.e5 = Block(512, 512, add_norm=True, add_drop=False, add_activation=True, down=True, activation_fun="leaky")
        self.e6 = Block(512, 512, add_norm=True, add_drop=False, add_activation=True, down=True, activation_fun="leaky")

        self.bottleneck = Block(512, 512, add_norm=False, add_drop=False, add_activation=True, down=True, activation_fun="leaky")

        self.d1 = Block(512, 512, add_norm=True, add_drop=True, add_activation=True, down=False, activation_fun="relu")
        self.d2 = Block(1024, 512, add_norm=True, add_drop=True, add_activation=True, down=False, activation_fun="relu")
        self.d3 = Block(1024, 512, add_norm=True, add_drop=True, add_activation=True, down=False, activation_fun="relu")
        self.d4 = Block(1024, 512, add_norm=False, add_drop=False, add_activation=True, down=False, activation_fun="relu")
        self.d5 = Block(1024, 256, add_norm=False, add_drop=False, add_activation=True, down=False, activation_fun="relu")
        self.d6 = Block(512, 128, add_norm=False, add_drop=False, add_activation=True, down=False, activation_fun="relu")
        self.d7 = Block(256, 64, add_norm=False, add_drop=False, add_activation=True, down=False, activation_fun="relu")

        self.out = nn.Sequential(
            nn.ConvTranspose2d(128, in_ch, kernel_size=4, stride=2, padding=1),
            nn.Tanh()
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor: # [batch, channels, height, width]
        # encoding
        in1_out = self.in1(x)
        e1_out = self.e1(in1_out)
        e2_out = self.e2(e1_out)
        e3_out = self.e3(e2_out)
        e4_out = self.e4(e3_out)
        e5_out = self.e5(e4_out)
        e6_out = self.e6(e5_out)
        b_out = self.bottleneck(e6_out)

        # decoding
        d1_out = self.d1(b_out)
        d2_out = self.d2(torch.cat([d1_out, e6_out], dim=1))
        d3_out = self.d3(torch.cat([d2_out, e5_out], dim=1))
        d4_out = self.d4(torch.cat([d3_out, e4_out], dim=1))
        d5_out = self.d5(torch.cat([d4_out, e3_out], dim=1))
        d6_out = self.d6(torch.cat([d5_out, e2_out], dim=1))
        d7_out = self.d7(torch.cat([d6_out, e1_out], dim=1))

        output = self.out(torch.cat([d7_out, in1_out], dim=1))

        return output

# %%
# !gcloud config get-value project
# !gcloud config set project sandbox-project-462110
# Out:
# sandbox-project-462110
# Updated property [core/project].

# %%
class Logger:

    def __init__(self, log_dir: str, log_image_dir: str, checkpoint_dir: str, validation_data_handler):
        self.writer = SummaryWriter(log_dir)
        self.log_image_dir = log_image_dir
        self.checkpoint_dir = checkpoint_dir
        self.val_handler = validation_data_handler
        # Use the authenticated filesystem object
        self.client = gcs.Client(credentials=credentials)
        self.bucket = self.client.bucket(bucket_name=BUCKET_NAME)

    def log_scalar(self, tag: str, value: float, batch: int, epoch: int):
        self.writer.add_scalar(tag, value, (10000*epoch + batch)/10000)

    def log_image(self, tag: str, generator, batch: int, epoch: int):
        x, y = next(iter(self.val_handler))
        x, y = x.to("cuda"), y.to("cuda")
        generator.eval()
        with torch.no_grad():
            with torch.autocast("cuda"):
                y_fake = generator(x)
            img = torch.cat((x, y, y_fake), 0) * 0.5 + 0.5
            file_name = f"{self.log_image_dir}/{tag}_{epoch}_{batch}.png"
            save_image(img, file_name)
            self._save_to_gcs(BUCKET_NAME, file_name)

        generator.train()

    def save_checkpoint(self, gen_state: dict, disc_state: dict, gen_opt_state: dict, disc_opt_state: dict, epoch: int):
        file_name = f"{self.checkpoint_dir}/checkpoint_{epoch}_{dt.datetime.now().strftime('%Y_%m_%d__%H_%M_%S')}.pt"
        torch.save({
            'epoch': epoch,
            'gen_state_dict': gen_state,
            'disc_state_dict': disc_state,
            'gen_opt_state_dict': gen_opt_state,
            'disc_opt_state_dict': disc_opt_state
        }, file_name)
        self._save_to_gcs(BUCKET_NAME, file_name)


    def _save_to_gcs(self, bucket_name: str, file_name: str):
        blob = self.bucket.blob(file_name)
        with open(file_name, "rb") as f:
            blob.upload_from_file(f)

        os.remove(file_name)

# %%
# if __name__ == "__main__":

# parser = argparse.ArgumentParser()
# parser.add_argument("--epoch", type=int, default=0, help="starting_epoch")
# parser.add_argument("--num_epochs", type=int, default=EPOCHS, help="number of epochs")
# parser.add_argument("--batch_size", type=int, default=BATCH_SIZE, help="size of the batches")
# parser.add_argument("--lr", type=float, default=LEARNING_RATE, help="adam: learning rate")
# parser.add_argument("--b1", type=float, default=BETA1, help="adam: decay of first order momentum of gradient")
# parser.add_argument("--b2", type=float, default=BETA2, help="adam: decay of first order momentum of gradient")
# parser.add_argument("--train_path", type=str, default="data/building_facade/train", help="root path of the dataset")
# parser.add_argument("--val_path", type=str, default="data/building_facade/test", help="root path of the dataset")
# parser.add_argument("--checkpoint_interval", type=int, default=30, help="interval between model checkpoints")
# parser.add_argument("--checkpoint_path", type=str, default="checkpoints", help="path to save checkpoints")
# parser.add_argument("--log_path", type=str, default="run/pix2pix", help="path to save logs")
# parser.add_argument("--results_path", type=str, default="results", help="path to save results")
# parser.add_argument("--load_model_path", type=str, default="", help="path to load model from")
# parser.add_argument("--L1lambda", type=float, default=100, help="weight for L1 loss")
# parser.add_argument("--transform_type", type=str, default="augment", help="augment data")
# opt = parser.parse_args()
BUCKET_NAME = "pix2pix-training-artifacts-1171246"
bucket_uri = f"gs://{BUCKET_NAME}"

class Opt:
    epoch = 0
    num_epochs = 200
    batch_size = 1
    lr = 2e-4
    b1 = 0.5
    b2 = 0.999
    train_path = "data/train"
    val_path = "data/val"
    checkpoint_interval = 50
    checkpoint_path = "checkpoints"
    log_path = "run/pix2pix"
    results_path = "results"
    load_model_path = ""
    L1lambda = 100
    transform_type = "augment"

opt = Opt()

if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using GPU")
else:
    device = torch.device("cpu")

if not os.path.exists(opt.log_path):
    os.makedirs(opt.log_path, exist_ok=True)

if not os.path.exists(opt.results_path):
    os.makedirs(opt.results_path, exist_ok=True)

if not os.path.exists(opt.checkpoint_path):
    os.makedirs(opt.checkpoint_path, exist_ok=True)


generator = UNETGenerator(3).to(device)
discriminator = PatchGAN70x70(3).to(device)

weights_init(generator)
weights_init(discriminator)

gen_opt = torch.optim.Adam(generator.parameters(), lr=opt.lr, betas=(opt.b1, opt.b2), weight_decay=1e-5)
disc_opt = torch.optim.Adam(discriminator.parameters(), lr=opt.lr, betas=(opt.b1, opt.b2), weight_decay=1e-5)

# Load checkpoints if available
if len(opt.load_model_path):
    state_dict = torch.load(opt.load_model_path)
    generator.load_state_dict(state_dict["gen_state_dict"])
    gen_opt.load_state_dict(state_dict["gen_opt_state_dict"])
    discriminator.load_state_dict(state_dict["disc_state_dict"])
    disc_opt.load_state_dict(state_dict["disc_opt_state_dict"])
    start_epoch = torch.load(state_dict["epoch"])
    print(f"Resuming training from epoch {opt.epoch}")

L1 = nn.L1Loss().to(device)
BCE = nn.BCEWithLogitsLoss().to(device)

datahandler = MapDataset(opt.train_path, target_side="left")
dataloader = DataLoader(datahandler, batch_size=opt.batch_size, shuffle=True)

datahandler_val = MapDataset(opt.val_path, target_side="left")
dataloader_val = DataLoader(datahandler_val, batch_size=opt.batch_size, shuffle=True)

logger = Logger(opt.log_path, opt.results_path, opt.checkpoint_path, dataloader_val)

generator_scaler = torch.GradScaler()
discriminator_scaler = torch.GradScaler()

# autocast to float16
# logging the results (losses, images)
# saving the model (checkpoints)
# option to resume training with checkpoints (also store optimizer states and epoch number)

for epoch in range(opt.epoch+1, opt.num_epochs+1):    # epochs
    loop = tqdm(dataloader, leave=True)

    for idx, (x, y) in enumerate(loop): # batches
        x, y = x.to(device), y.to(device)


        with torch.autocast("cuda"): # training the discriminator
            y_fake = generator(x)
            d_real = discriminator(x, y) # showing the discriminator the real image and real output
            d_fake = discriminator(x, y_fake.detach()) # showing the discriminator the real image and fake output

            d_real_loss = BCE(d_real, torch.ones_like(d_real))
            d_fake_loss = BCE(d_fake, torch.zeros_like(d_fake))

            d_loss = (d_real_loss + d_fake_loss) / 2


        disc_opt.zero_grad()
        discriminator_scaler.scale(d_loss).backward() #loss
        discriminator_scaler.step(disc_opt)
        discriminator_scaler.update()


        with torch.autocast("cuda"): # training the generator
            d_fake = discriminator(x, y_fake)
            g_fake_loss = BCE(d_fake, torch.ones_like(d_fake))
            l1 = L1(y_fake, y) * opt.L1lambda

            g_loss = g_fake_loss + l1

        gen_opt.zero_grad()
        generator_scaler.scale(g_loss).backward()
        generator_scaler.step(gen_opt)
        generator_scaler.update()

        if idx % 500 == 0 and idx != 0:
            logger.log_scalar("d_loss", d_loss.item(), idx, epoch)
            logger.log_scalar("g_loss", g_loss.item(), idx, epoch)
            logger.log_scalar("l1_loss", l1.item(), idx, epoch)
            logger.log_scalar("d_fake_loss", d_fake_loss.item(), idx, epoch)
            logger.log_scalar("d_real_loss", d_real_loss.item(), idx, epoch)
            logger.log_scalar("g_fake_loss", g_fake_loss.item(), idx, epoch)
            logger.log_image("result", generator, idx, epoch)

    # loop.set_postfix(d_loss=d_loss.item(), g_loss=g_loss.item())

    if epoch % opt.checkpoint_interval == 0 and epoch != 0:
        logger.save_checkpoint(generator.state_dict(), discriminator.state_dict(), gen_opt.state_dict(), disc_opt.state_dict(), epoch)
# Out:
# Using GPU
# 100%|██████████| 1096/1096 [01:00<00:00, 18.14it/s]
# 100%|██████████| 1096/1096 [00:59<00:00, 18.38it/s]
# 100%|██████████| 1096/1096 [00:59<00:00, 18.45it/s]
# 100%|██████████| 1096/1096 [00:59<00:00, 18.44it/s]
# 100%|██████████| 1096/1096 [00:59<00:00, 18.41it/s]
# 100%|██████████| 1096/1096 [00:59<00:00, 18.47it/s]
# 100%|██████████| 1096/1096 [00:59<00:00, 18.45it/s]
# 100%|██████████| 1096/1096 [00:59<00:00, 18.50it/s]
# 100%|██████████| 1096/1096 [00:59<00:00, 18.33it/s]
# 100%|██████████| 1096/1096 [00:58<00:00, 18.62it/s]
# 100%|██████████| 1096/1096 [00:59<00:00, 18.47it/s]
# 100%|██████████| 1096/1096 [00:59<00:00, 18.54it/s]
# 100%|██████████| 1096/1096 [00:59<00:00, 18.33it/s]
# 100%|██████████| 1096/1096 [00:59<00:00, 18.51it/s]
# 100%|██████████| 1096/1096 [00:59<00:00, 18.32it/s]
# 100%|██████████| 1096/1096 [00:59<00:00, 18.42it/s]
# 100%|██████████| 1096/1096 [00:58<00:00, 18.61it/s]
# 100%|██████████| 1096/1096 [00:59<00:00, 18.46it/s]
# 100%|██████████| 1096/1096 [00:59<00:00, 18.37it/s]
# 100%|██████████| 1096/1096 [00:59<00:00, 18.36it/s]
# 100%|██████████| 1096/1096 [00:59<00:00, 18.38it/s]
#  83%|████████▎ | 910/1096 [00:48<00:09, 18.95it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-95-36f8a7b14ae9> in <cell line: 0>()
#      97     loop = tqdm(dataloader, leave=True)
#      98
# ---> 99     for idx, (x, y) in enumerate(loop): # batches
#     100         x, y = x.to(device), y.to(device)
#     101
#
# /usr/local/lib/python3.11/dist-packages/tqdm/std.py in __iter__(self)
#    1179
#    1180         try:
# -> 1181             for obj in iterable:
#    1182                 yield obj
#    1183                 # Update and possibly print the progressbar.
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     706                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707                 self._reset()  # type: ignore[call-arg]
# --> 708             data = self._next_data()
#     709             self._num_yielded += 1
#     710             if (
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     762     def _next_data(self):
#     763         index = self._next_index()  # may raise StopIteration
# --> 764         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765         if self._pin_memory:
#     766             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# <ipython-input-93-69757912357a> in __getitem__(self, index)
#      43         img_file = self.list_files[index]
#      44         img_path = os.path.join(self.root_dir, img_file)
# ---> 45         image = np.array(Image.open(img_path))
#      46         input_image = image[:, :self.size, :]
#      47         target_image = image[:, self.size:, :]
#
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py in __array_interface__(self)
#     733             new["data"] = self.tobytes("raw", "L")
#     734         else:
# --> 735             new["data"] = self.tobytes()
#     736         new["shape"], new["typestr"] = _conv_type_shape(self)
#     737         return new
#
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py in tobytes(self, encoder_name, *args)
#     792             encoder_args = self.mode
#     793
# --> 794         self.load()
#     795
#     796         if self.width == 0 or self.height == 0:
#
# /usr/local/lib/python3.11/dist-packages/PIL/ImageFile.py in load(self)
#     387
#     388                             b = b + s
# --> 389                             n, err_code = decoder.decode(b)
#     390                             if n < 0:
#     391                                 break
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

# %%
# !mkdir data/{train,test}

# %%
for img in os.listdir("data/trainB"):
  imgA_path = "data/trainA/" + img.replace("B", "A")
  imgB_path = "data/trainB/" + img

  imgA = np.array(Image.open(imgA_path))
  imgB = np.array(Image.open(imgB_path))

  res = np.hstack([imgB, imgA])
  im = Image.fromarray(res, mode="RGB")
  im.save(f"data/train/{img}", format="JPEG")
  # plt.imshow(res)
  # plt.show()

# %%
for img in os.listdir("data/testA"):
  imgA_path = "data/testA/" + img
  imgB_path = "data/testB/" + img

  imgA = np.array(Image.open(imgA_path))
  imgB = np.array(Image.open(imgB_path))

  res = np.hstack([imgB, imgA])
  im = Image.fromarray(res, mode="RGB")
  im.save(f"data/test/{img}", format="JPEG")
  # plt.imshow(res)
  # plt.show()

# %%
# !rm -rf data/test/*

# %%
# !rm -rf data/train/*

# %%
# !rm -rf results/*

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("vikramtiwari/pix2pix-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/vikramtiwari/pix2pix-dataset?dataset_version_number=2...
# 100%|██████████| 2.40G/2.40G [00:23<00:00, 109MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/vikramtiwari/pix2pix-dataset/versions/2

# %%
# !mkdir data

# %%
# !cp -r /root/.cache/kagglehub/datasets/vikramtiwari/pix2pix-dataset/versions/2/maps/maps/* data/

# %%
pix2pix_service_account_json = userdata.get("PIX2PIX_SA_JSON")

# %%
import google.auth
from google.oauth2 import service_account
import json

credentials = service_account.Credentials.from_service_account_info(json.loads(pix2pix_service_account_json))

# %%
import google.cloud.storage as gcs

# %%
# authorize with credentials to use google cloud storage
client = gcs.Client(credentials=credentials)

# %%
BUCKET_NAME = "pix2pix-training-artifacts-1171246"
bucket = client.bucket(bucket_name=BUCKET_NAME)

# %%
list(bucket.list_blobs())
# Out:
# []

# %%
# upload test.txt to the bucket
blob = bucket.blob("test.txt")
blob.upload_from_filename("test.txt")

# %%
# upload whole data folder to the bucket

blob = bucket.blob("data_maps")
blob.upload_from_filename("data")
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-24-3164a7abb98c> in <cell line: 0>()
#       2
#       3 blob = bucket.blob("data_maps")
# ----> 4 blob.upload_from_filename("data")
#
# /usr/lib/python3.11/contextlib.py in inner(*args, **kwds)
#      79         def inner(*args, **kwds):
#      80             with self._recreate_cm():
# ---> 81                 return func(*args, **kwds)
#      82         return inner
#      83
#
# /usr/local/lib/python3.11/dist-packages/google/cloud/storage/blob.py in upload_from_filename(self, filename, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    3004         """
#    3005
# -> 3006         self._handle_filename_and_upload(
#    3007             filename,
#    3008             content_type=content_type,
#
# /usr/local/lib/python3.11/dist-packages/google/cloud/storage/blob.py in _handle_filename_and_upload(self, filename, content_type, *args, **kwargs)
#    2880         content_type = self._get_content_type(content_type, filename=filename)
#    2881
# -> 2882         with open(filename, "rb") as file_obj:
#    2883             total_bytes = os.fstat(file_obj.fileno()).st_size
#    2884             self._prep_and_do_upload(
#
# IsADirectoryError: [Errno 21] Is a directory: 'data'

# %%
import os

def upload_folder_to_bucket(bucket, folder_path, destination_prefix=""):
    """Uploads all files in a folder to a Google Cloud Storage bucket.

    Args:
        bucket: The bucket object to upload to.
        folder_path: The path to the local folder to upload.
        destination_prefix: A prefix to add to the blob names in the bucket.
    """
    for root, _, files in os.walk(folder_path):
        for file in files:
            local_file_path = os.path.join(root, file)
            # Create the destination path in the bucket, preserving the folder structure
            relative_path = os.path.relpath(local_file_path, folder_path)
            destination_blob_name = os.path.join(destination_prefix, relative_path)

            blob = bucket.blob(destination_blob_name)
            blob.upload_from_filename(local_file_path)
            print(f"Uploaded {local_file_path} to gs://{bucket.name}/{destination_blob_name}")

# Specify the local folder path and the desired destination prefix in the bucket
local_folder_path = "data"  # Replace with the path to your local folder
destination_prefix = "data_maps"  # Replace with the desired prefix in your bucket

upload_folder_to_bucket(bucket, local_folder_path, destination_prefix)
# Out:
# Uploaded data/train/649.jpg to gs://pix2pix-training-artifacts-1171246/data_maps/train/649.jpg
# Uploaded data/train/308.jpg to gs://pix2pix-training-artifacts-1171246/data_maps/train/308.jpg
# Uploaded data/train/698.jpg to gs://pix2pix-training-artifacts-1171246/data_maps/train/698.jpg
# Uploaded data/train/772.jpg to gs://pix2pix-training-artifacts-1171246/data_maps/train/772.jpg
# Uploaded data/train/275.jpg to gs://pix2pix-training-artifacts-1171246/data_maps/train/275.jpg
# Uploaded data/train/183.jpg to gs://pix2pix-training-artifacts-1171246/data_maps/train/183.jpg
# Uploaded data/train/184.jpg to gs://pix2pix-training-artifacts-1171246/data_maps/train/184.jpg
# Uploaded data/train/612.jpg to gs://pix2pix-training-artifacts-1171246/data_maps/train/612.jpg
# Uploaded data/train/782.jpg to gs://pix2pix-training-artifacts-1171246/data_maps/train/782.jpg
# Uploaded data/train/339.jpg to gs://pix2pix-training-artifacts-1171246/data_maps/train/339.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-93225b5026e1> in <cell line: 0>()
#      24 destination_prefix = "data_maps"  # Replace with the desired prefix in your bucket
#      25
# ---> 26 upload_folder_to_bucket(bucket, local_folder_path, destination_prefix)
#
# <ipython-input-25-93225b5026e1> in upload_folder_to_bucket(bucket, folder_path, destination_prefix)
#      17
#      18             blob = bucket.blob(destination_blob_name)
# ---> 19             blob.upload_from_filename(local_file_path)
#      20             print(f"Uploaded {local_file_path} to gs://{bucket.name}/{destination_blob_name}")
#      21
#
# /usr/lib/python3.11/contextlib.py in inner(*args, **kwds)
#      79         def inner(*args, **kwds):
#      80             with self._recreate_cm():
# ---> 81                 return func(*args, **kwds)
#      82         return inner
#      83
#
# /usr/local/lib/python3.11/dist-packages/google/cloud/storage/blob.py in upload_from_filename(self, filename, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    3004         """
#    3005
# -> 3006         self._handle_filename_and_upload(
#    3007             filename,
#    3008             content_type=content_type,
#
# /usr/local/lib/python3.11/dist-packages/google/cloud/storage/blob.py in _handle_filename_and_upload(self, filename, content_type, *args, **kwargs)
#    2882         with open(filename, "rb") as file_obj:
#    2883             total_bytes = os.fstat(file_obj.fileno()).st_size
# -> 2884             self._prep_and_do_upload(
#    2885                 file_obj,
#    2886                 content_type=content_type,
#
# /usr/local/lib/python3.11/dist-packages/google/cloud/storage/blob.py in _prep_and_do_upload(self, file_obj, rewind, size, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2698
#    2699         try:
# -> 2700             created_json = self._do_upload(
#    2701                 client,
#    2702                 file_obj,
#
# /usr/local/lib/python3.11/dist-packages/google/cloud/storage/blob.py in _do_upload(self, client, stream, content_type, size, num_retries, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2504
#    2505         if size is not None and size <= _MAX_MULTIPART_SIZE:
# -> 2506             response = self._do_multipart_upload(
#    2507                 client,
#    2508                 stream,
#
# /usr/local/lib/python3.11/dist-packages/google/cloud/storage/blob.py in _do_multipart_upload(self, client, stream, content_type, size, num_retries, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2005             api_request=args,
#    2006         ):
# -> 2007             response = upload.transmit(
#    2008                 transport, data, object_metadata, content_type, timeout=timeout
#    2009             )
#
# /usr/local/lib/python3.11/dist-packages/google/resumable_media/requests/upload.py in transmit(self, transport, data, metadata, content_type, timeout)
#     151             return result
#     152
# --> 153         return _request_helpers.wait_and_retry(
#     154             retriable_request, self._get_status_code, self._retry_strategy
#     155         )
#
# /usr/local/lib/python3.11/dist-packages/google/resumable_media/requests/_request_helpers.py in wait_and_retry(func, get_status_code, retry_strategy)
#     153         error = None
#     154         try:
# --> 155             response = func()
#     156         except _CONNECTION_ERROR_CLASSES as e:
#     157             error = e  # Fall through to retry, if there are retries left.
#
# /usr/local/lib/python3.11/dist-packages/google/resumable_media/requests/upload.py in retriable_request()
#     143         # Wrap the request business logic in a function to be retried.
#     144         def retriable_request():
# --> 145             result = transport.request(
#     146                 method, url, data=payload, headers=headers, timeout=timeout
#     147             )
#
# /usr/local/lib/python3.11/dist-packages/google/auth/transport/requests.py in request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     535
#     536         with TimeoutGuard(remaining_time) as guard:
# --> 537             response = super(AuthorizedSession, self).request(
#     538                 method,
#     539                 url,
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.11/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532         # Receive the response from the server
#     533         try:
# --> 534             response = conn.getresponse()
#     535         except (BaseSSLError, OSError) as e:
#     536             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connection.py in getresponse(self)
#     514
#     515         # Get the response from http.client.HTTPConnection
# --> 516         httplib_response = super().getresponse()
#     517
#     518         try:
#
# /usr/lib/python3.11/http/client.py in getresponse(self)
#    1393         try:
#    1394             try:
# -> 1395                 response.begin()
#    1396             except ConnectionError:
#    1397                 self.close()
#
# /usr/lib/python3.11/http/client.py in begin(self)
#     323         # read until we get a non-100 response
#     324         while True:
# --> 325             version, status, reason = self._read_status()
#     326             if status != CONTINUE:
#     327                 break
#
# /usr/lib/python3.11/http/client.py in _read_status(self)
#     284
#     285     def _read_status(self):
# --> 286         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287         if len(line) > _MAXLINE:
#     288             raise LineTooLong("status line")
#
# /usr/lib/python3.11/socket.py in readinto(self, b)
#     716         while True:
#     717             try:
# --> 718                 return self._sock.recv_into(b)
#     719             except timeout:
#     720                 self._timeout_occurred = True
#
# /usr/lib/python3.11/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1312                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313                   self.__class__)
# -> 1314             return self.read(nbytes, buffer)
#    1315         else:
#    1316             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.11/ssl.py in read(self, len, buffer)
#    1164         try:
#    1165             if buffer is not None:
# -> 1166                 return self._sslobj.read(len, buffer)
#    1167             else:
#    1168                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# !gsutil cp -r data gs://pix2pix-training-artifacts-1171246/data_maps
# Out:
# ServiceException: 401 Anonymous caller does not have storage.objects.list access to the Google Cloud Storage bucket. Permission 'storage.objects.list' denied on resource (or it may not exist).

# %%
# First, save your service account JSON to a file
with open("service_account.json", "w") as f:
    f.write(pix2pix_service_account_json)

# %%
# Then, activate the service account using gcloud
# !gcloud auth activate-service-account --key-file=service_account.json
# Out:
# Activated service account credentials for: [pix2pix@sandbox-project-462110.iam.gserviceaccount.com]

# %% [markdown]
# After running these commands, you should be able to use `gsutil cp` to upload your data.

# %%
# !gsutil -m cp -r data gs://pix2pix-training-artifacts-1171246/data_maps
# Out:
# Copying file://data/train/649.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/308.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/772.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/698.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/184.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/183.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/275.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/612.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/782.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/339.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/759.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/721.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/887.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/197.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/861.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/135.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/664.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/185.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/639.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/165.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/852.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/579.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/973.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/37.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/760.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/244.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/471.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/704.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/20.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/180.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/291.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/938.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/113.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/525.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/501.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/764.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/634.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/49.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/869.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/789.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/911.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/571.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/237.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/273.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/195.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/871.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/378.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/815.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/992.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/331.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/176.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1066.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1041.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/320.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/962.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/437.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/557.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/705.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/466.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/940.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/981.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/154.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/672.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/343.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/357.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/526.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/693.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1006.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/396.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/535.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/876.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/958.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/708.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/472.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/590.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/987.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/633.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/944.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/337.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/285.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/401.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/738.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/895.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/33.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/617.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/430.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/484.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/139.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1051.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/372.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/39.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/575.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1018.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1008.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/239.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/800.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/659.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/189.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1029.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/860.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/908.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1031.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/121.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1004.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/504.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/890.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/519.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/252.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/353.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/167.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/95.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/23.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/173.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/834.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/798.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/369.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/96.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/872.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/329.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/335.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1001.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/713.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/52.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/223.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1053.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/297.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/812.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1074.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/640.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/512.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/572.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1089.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/385.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/6.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/265.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/210.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/207.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1022.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/397.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/153.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/818.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/748.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/450.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/643.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/865.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/127.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/736.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1028.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1011.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/388.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/831.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/316.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/490.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/260.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/965.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/921.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/374.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/793.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/278.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/775.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/717.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/370.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/514.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/722.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/638.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/523.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/152.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/277.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1075.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/465.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/233.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/788.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/158.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/214.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1085.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/919.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/816.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1021.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/276.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1071.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/777.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/248.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/658.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/991.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/408.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/124.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/431.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/109.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/804.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1000.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/89.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/628.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/696.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/727.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/948.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/326.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/138.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/59.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/469.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1045.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1003.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/995.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/145.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/850.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/295.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/999.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/41.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/563.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/461.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/754.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/149.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/647.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/103.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/341.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/40.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/517.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/837.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/737.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/69.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/864.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/288.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/463.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/458.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1038.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/527.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/193.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/416.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1025.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/360.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/426.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/836.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/827.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/58.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/666.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/545.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1064.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/532.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/780.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/724.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/162.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/681.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/66.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/346.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/257.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/542.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/433.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/123.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/57.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1023.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/354.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/615.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/497.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/299.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/582.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/642.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/945.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/133.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/292.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/161.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/102.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/272.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/763.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/912.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/673.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/253.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1081.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/807.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/499.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/199.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/483.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/961.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1052.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/332.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/553.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/608.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/824.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/368.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/845.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/858.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/670.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/101.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/714.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/573.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1033.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/387.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/594.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/482.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/115.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1073.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/728.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/72.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1070.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/671.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/22.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/399.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/599.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/36.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/144.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/875.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/311.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/510.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/303.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/971.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/208.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/909.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/306.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/218.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/415.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/849.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/221.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1012.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/402.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/534.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/384.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/715.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/651.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/169.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/682.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/84.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/574.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1026.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/883.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/578.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/539.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/90.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/839.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/11.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/653.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/509.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/580.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/263.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/817.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/376.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/359.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/281.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/422.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/80.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1095.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/442.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/99.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/955.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/234.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/820.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/960.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/172.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/626.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/400.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/190.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/505.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/456.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/870.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/403.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/838.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/521.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/363.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/16.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/650.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/655.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/170.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/43.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/181.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/267.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/855.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/407.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1086.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/630.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/546.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/280.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/694.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/394.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/255.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/494.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/993.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/942.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/12.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/358.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1044.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/787.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/435.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/94.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/347.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/707.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/301.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/61.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/14.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/98.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/423.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/241.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/957.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/621.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/88.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/188.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/284.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/879.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/392.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/783.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/660.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/383.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/515.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/54.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/593.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/723.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/240.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/627.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/344.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1058.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/455.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1087.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1054.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/990.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/143.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/77.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/556.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1096.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1037.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/803.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/951.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/114.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/487.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/122.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/548.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/254.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/86.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/293.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/305.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/38.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/405.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/791.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/206.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/157.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/440.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/880.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/110.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/27.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/678.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/513.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/205.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/500.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/922.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/129.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/691.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/345.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/540.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/30.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/709.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/595.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/937.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/137.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/106.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/55.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/927.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/32.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/734.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/242.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/473.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/543.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/81.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/492.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/175.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/697.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/495.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/131.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/467.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/846.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1014.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/112.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/315.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/229.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/496.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/841.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/589.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/806.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1057.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/741.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/489.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/491.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1067.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1013.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/389.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1048.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/920.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/635.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/459.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/825.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/933.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/974.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/877.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/873.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/868.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/336.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/859.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/699.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/395.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/743.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/917.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/657.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/729.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/424.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/893.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/10.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/604.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/916.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/47.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1002.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/935.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/78.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/317.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/247.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/690.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/164.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/196.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/434.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/878.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/560.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/614.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/632.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1050.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/761.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/236.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/733.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/355.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/675.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1063.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/613.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/569.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/327.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/688.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/156.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1065.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/756.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/584.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1005.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/51.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/746.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/74.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/171.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/631.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/251.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/570.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/485.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/134.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1091.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/381.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/799.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/689.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/126.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/762.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/187.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1055.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/953.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/758.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/725.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/309.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/18.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/302.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/924.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/874.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1083.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/182.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/256.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1056.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/949.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1020.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/966.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/863.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/4.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/929.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/468.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/652.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/819.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/71.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/851.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/905.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/19.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/42.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/511.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/209.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/386.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/79.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/390.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/479.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/147.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/262.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/616.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1059.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/894.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/566.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/220.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/976.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/745.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/321.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/507.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/159.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/151.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/547.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/518.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/972.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/404.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/979.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/950.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/470.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1019.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/453.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/56.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/117.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/212.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/3.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/17.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/797.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/116.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/776.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/970.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/862.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/460.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/522.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/925.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/441.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/118.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/564.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/200.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/906.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/603.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/610.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/830.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/695.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/44.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/750.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/34.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/994.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/648.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1082.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/930.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/867.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/622.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/520.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/996.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/843.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/641.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/67.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/428.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/544.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/141.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/784.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/771.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/718.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/296.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/977.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/702.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/687.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/530.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/243.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/279.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/391.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/298.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/661.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/536.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/226.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/568.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1009.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/87.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/516.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1032.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/833.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/304.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/897.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/959.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/910.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1010.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/219.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/600.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/885.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/64.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/808.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/904.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/625.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/813.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/294.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/884.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/104.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/174.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/607.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/932.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/601.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/711.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/261.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1072.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/954.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/805.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/217.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/703.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/822.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/934.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/810.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/286.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/228.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/677.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/842.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/847.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/76.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/31.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/551.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1092.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/531.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/215.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/755.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/35.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/558.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/274.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/986.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1084.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/371.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/168.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/474.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/62.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/333.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/412.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/282.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1069.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/947.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/892.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/2.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/644.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/314.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/409.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/382.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/801.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/429.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1024.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/629.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/375.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/457.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1076.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/283.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/835.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/100.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/427.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/720.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/448.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/751.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/533.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/325.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/445.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/829.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/591.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/939.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/719.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/1047.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/148.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/29.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/503.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/310.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/915.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/926.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/969.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/814.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/249.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/583.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/140.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/866.jpg [Content-Type=image/jpeg]...
# Copying file://data/train/477.jpg [Content-Type=image/jpeg]...
# ...
# Copying file://data/val/269.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/712.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/342.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/988.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/227.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/83.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/684.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/550.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/506.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1060.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/856.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/178.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/163.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/901.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/701.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/896.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/361.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/809.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/290.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/93.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/537.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/592.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/765.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/45.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/984.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1027.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/105.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/757.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/334.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/130.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1040.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/414.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/823.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/502.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/68.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/349.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/618.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/191.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/840.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/476.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/931.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/379.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1030.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/444.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/587.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1068.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/665.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/668.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/907.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/146.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/271.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/636.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/752.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/586.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/620.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/900.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/192.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/213.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1035.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/322.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/585.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/348.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/13.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/881.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/952.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/108.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/552.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1034.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1039.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/380.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/914.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/425.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/73.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1077.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/246.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/235.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/768.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/742.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1043.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/128.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/393.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/270.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/436.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/985.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/9.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/785.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/654.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/480.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1088.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/222.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/998.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/362.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/623.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/454.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/781.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/918.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/903.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/313.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/417.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/646.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/410.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/749.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/964.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/889.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/25.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/941.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/792.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/529.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/968.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/46.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/735.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/606.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1062.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/462.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/913.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/478.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/451.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/5.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/549.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/232.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/848.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/581.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/778.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/980.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/795.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/493.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/142.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/60.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/891.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/982.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/111.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/624.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/120.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/983.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/177.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/854.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/97.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/198.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/611.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/538.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/366.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/731.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/230.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/132.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/50.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/956.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/662.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/377.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/421.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1015.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/328.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/946.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1049.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/508.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/619.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/943.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/24.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/565.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/802.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/420.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/710.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/8.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/446.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/447.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/767.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/224.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/936.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/82.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/853.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/432.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/323.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/406.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/160.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/350.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/307.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/726.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/602.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/576.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/238.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/452.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/300.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/419.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/567.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/413.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/15.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/541.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/997.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/844.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/107.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/898.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/119.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/732.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/562.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/319.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/53.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/605.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/700.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/216.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/85.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/888.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/656.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/826.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/963.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/554.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/373.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/150.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/481.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/989.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1078.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/438.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/669.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/588.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/351.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/555.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/524.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/28.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1046.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/561.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1061.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/967.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/289.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/902.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/645.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/577.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/398.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/70.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/330.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/464.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1016.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/204.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/975.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/753.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/48.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1017.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/811.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1007.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/730.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/739.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/324.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/449.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1036.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/439.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/786.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/259.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/923.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/411.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/683.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/266.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/740.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/250.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/364.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/356.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1094.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/692.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/1042.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/680.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/774.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/194.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/352.jpg [Content-Type=image/jpeg]...
# Copying file://data/val/486.jpg [Content-Type=image/jpeg]...
# - [2.2k/2.2k files][241.3 MiB/241.3 MiB] 100% Done   1.2 MiB/s ETA 00:00:00
# Operation completed over 2.2k objects/241.3 MiB.

# %%
# !gsutil help options
# Out:
# NAME
#   options - Global Command Line Options
#
#
# DESCRIPTION
#   gsutil supports separate options for the top-level gsutil command and
#   the individual sub-commands (like cp, rm, etc.) The top-level options
#   control behavior of gsutil that apply across commands. For example, in
#   the command:
#
#     gsutil -m cp -p file gs://bucket/obj
#
#   the -m option applies to gsutil, while the -p option applies to the cp
#   sub-command.
#
#
# OPTIONS
#   -D          Shows HTTP requests/headers and additional debug info needed
#               when posting support requests, including exception stack traces.
#
#               CAUTION: The output from using this flag includes authentication
#               credentials. Before including this flag in your command, be sure
#               you understand how the command's output is used, and, if
#               necessary, remove or redact sensitive information.
#
#   -DD         Same as -D, plus HTTP upstream payload.
#
#   -h          Allows you to specify certain HTTP headers, for example:
#
#                 gsutil -h "Cache-Control:public,max-age=3600" \
#                        -h "Content-Type:text/html" cp ...
#
#               Note that you need to quote the headers/values that
#               contain spaces (such as "Content-Disposition: attachment;
#               filename=filename.ext"), to avoid having the shell split them
#               into separate arguments.
#
#               The following headers are stored as object metadata and used
#               in future requests on the object:
#
#                 Cache-Control
#                 Content-Disposition
#                 Content-Encoding
#                 Content-Language
#                 Content-Type
#
#               The following headers are used to check data integrity:
#
#                 Content-MD5
#
#               gsutil also supports custom metadata headers with a matching
#               Cloud Storage Provider prefix, such as:
#
#                 x-goog-meta-
#
#               Note that for gs:// URLs, the Cache Control header is specific to
#               the API being used. The XML API accepts any cache control headers
#               and returns them during object downloads.  The JSON API respects
#               only the public, private, no-cache, max-age, and no-transform
#               cache control headers.
#
#               See "gsutil help setmeta" for the ability to set metadata
#               fields on objects after they have been uploaded.
#
#   -i          Allows you to use the configured credentials to impersonate a
#               service account, for example:
#
#                 gsutil -i "service-account@google.com" ls gs://pub
#
#               Note that this setting will be ignored by the XML API and S3. See
#               'gsutil help creds' for more information on impersonating service
#               accounts.
#
#   -m          Causes supported operations (acl ch, acl set, cp, mv, rm, rsync,
#               and setmeta) to run in parallel. This can significantly improve
#               performance if you are performing operations on a large number of
#               files over a reasonably fast network connection.
#
#               gsutil performs the specified operation using a combination of
#               multi-threading and multi-processing. The number of threads
#               and processors are determined by ``parallel_thread_count`` and
#               ``parallel_process_count``, respectively. These values are set in
#               the .boto configuration file or specified in individual requests
#               with the ``-o`` top-level flag. Because gsutil has no built-in
#               support for throttling requests, you should experiment with these
#               values. The optimal values can vary based on a number of factors,
#               including network speed, number of CPUs, and available memory.
#
#               Using the -m option can consume a significant amount of network
#               bandwidth and cause problems or make your performance worse if
#               you use a slower network. For example, if you start a large rsync
#               operation over a network link that's also used by a number of
#               other important jobs, there could be degraded performance in
#               those jobs. Similarly, the -m option can make your performance
#               worse, especially for cases that perform all operations locally,
#               because it can "thrash" your local disk.
#
#               To prevent such issues, reduce the values for
#               ``parallel_thread_count`` and ``parallel_process_count``, or stop
#               using the -m option entirely. One tool that you can use to limit
#               how much I/O capacity gsutil consumes and prevent it from
#               monopolizing your local disk is `ionice
#               <http://www.tutorialspoint.com/unix_commands/ionice.htm>`_
#               (built in to many Linux systems). For example, the following
#               command reduces the I/O priority of gsutil so it doesn't
#               monopolize your local disk:
#
#                 ionice -c 2 -n 7 gsutil -m rsync -r ./dir gs://some bucket
#
#               If a download or upload operation using parallel transfer fails
#               before the entire transfer is complete (e.g. failing after 300 of
#               1000 files have been transferred), you must restart the entire
#               transfer.
#
#               Also, although most commands normally fail upon encountering an
#               error when the -m flag is disabled, all commands continue to try
#               all operations when -m is enabled with multiple threads or
#               processes, and the number of failed operations (if any) are
#               reported as an exception at the end of the command's execution.
#
#   -o          Override values in the `boto configuration file
#               <https://cloud.google.com/storage/docs/boto-gsutil>`_ for the
#               current command, in the format ``<section>:<name>=<value>``. For
#               example, ``gsutil -o "GSUtil:parallel_thread_count=4" ...``. This
#               does not pass the option to gsutil integration tests and does not
#               change the values that are saved in the boto configuration file.
#
#   -q          Causes gsutil to perform operations quietly, i.e., without
#               reporting progress indicators of files being copied or removed,
#               etc. Errors are still reported. This option can be useful for
#               running gsutil from a cron job that logs its output to a file, for
#               which the only information desired in the log is failures.
#
#   -u          Allows you to specify the ID or number of a user project to be
#               billed for the request. For example:
#
#                 gsutil -u "bill-this-project" cp ...
